# %%
import pandas as pd

# df = pd.read_csv("../data/interim/201901-fordgobike-tripdata.csv")
df = pd.read_csv("../data/interim/202607-baywheels-tripdata.csv")
# df["user_type"].unique()
df["rideable_type"].unique()
# print(df.columns)
# print(tuple(df.columns))
# print(df.dtypes)
# print(df.shape)
# Out:
# array(['electric_bike', 'classic_bike'], dtype=object)

# %%
from pathlib import Path

previous_columns = None

for path in sorted(Path("../data/interim").glob("*.csv")):
    df = pd.read_csv(path, nrows=0)
    current_columns = tuple(df.columns)

    if current_columns != previous_columns:
        print(path)
        print(current_columns)
        previous_columns = current_columns
# Out:
# ../data/interim/201901-fordgobike-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'bike_share_for_all_trip')
# ../data/interim/201906-baywheels-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'bike_share_for_all_trip', 'rental_access_method')
# ../data/interim/201908-baywheels-tripdata.csv
# ...

# %%
# testing function for normalizing the modern schema to the new unified schema
import sys
sys.path.append("..")
from src.build_db import normalize_modern

df = pd.read_csv("../data/interim/202607-baywheels-tripdata.csv")
result = normalize_modern(df)
print(result.columns)
# print(result)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at', 'duration_sec',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
# testing function for normalizing the legacy schema to the new unified schema

from src.build_db import normalize_legacy

df = pd.read_csv("../data/interim/201911-baywheels-tripdata.csv")
result = normalize_legacy(df)
# print(result)
# result['member_casual'].unique()
result['member_casual'].isnull().sum()
# Out:
# /var/folders/rr/8kbc2tl546l5wtr7b5cs3kx00000gn/T/ipykernel_49236/2808208517.py:5: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/interim/201911-baywheels-tripdata.csv")
# np.int64(0)

# %%
from src.build_db import build_unified_dataset

print(build_unified_dataset())
# Out:
# /Users/kennedycassiday/coding-projects/baywheels-analysis/notebooks/../src/build_db.py:64: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# /Users/kennedycassiday/coding-projects/baywheels-analysis/notebooks/../src/build_db.py:64: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# /Users/kennedycassiday/coding-projects/baywheels-analysis/notebooks/../src/build_db.py:64: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# /Users/kennedycassiday/coding-projects/baywheels-analysis/notebooks/../src/build_db.py:64: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# ...
