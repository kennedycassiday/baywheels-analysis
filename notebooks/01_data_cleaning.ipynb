# %%
import pandas as pd

# df = pd.read_csv("../data/interim/201901-fordgobike-tripdata.csv")
df = pd.read_csv("../data/interim/202607-baywheels-tripdata.csv")
# df["user_type"].unique()
print(df.columns)
# print(tuple(df.columns))
# print(df.dtypes)
# print(df.shape)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
from pathlib import Path

previous_columns = None

for path in sorted(Path("../data/interim").glob("*.csv")):
    df = pd.read_csv(path, nrows=0)
    current_columns = tuple(df.columns)

    if current_columns != previous_columns:
        print(path)
        print(current_columns)
        previous_columns = current_columns
# Out:
# ../data/interim/201901-fordgobike-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'bike_share_for_all_trip')
# ../data/interim/201906-baywheels-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'bike_share_for_all_trip', 'rental_access_method')
# ../data/interim/201908-baywheels-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'bike_share_for_all_trip')
# ../data/interim/201911-baywheels-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'bike_share_for_all_trip', 'rental_access_method')
# ../data/interim/201912-baywheels-tripdata.csv
# ('duration_sec', 'start_time', 'end_time', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'rental_access_method')
# ../data/interim/202005-baywheels-tripdata.csv
# ('ride_id', 'rideable_type', 'started_at', 'ended_at', 'start_station_name', 'start_station_id', 'end_station_name', 'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng', 'member_casual')

# %%
import sys
sys.path.append("..")
from src.build_db import normalize_modern

df = pd.read_csv("../data/interim/202607-baywheels-tripdata.csv")
result = normalize_modern(df)
print(result)
# Out:
# 0         436.826
# 1          13.901
# 2         229.412
# 3          17.585
# 4         482.459
#            ...
# 585282    282.969
# 585283    625.680
# 585284    214.214
# 585285    342.674
# 585286    788.624
# Length: 585287, dtype: float64
# 0         436
# 1          13
# 2         229
# 3          17
# 4         482
